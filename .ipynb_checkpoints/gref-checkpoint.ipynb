# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import regex as re

# %% [markdown]
# #### BatteryManager Processer script

# %%
HEADER_PATTERN = 'BatteryMgr:DataCollectionService: onStartCommand: rawFields => '
DATA_PATTERN = 'BatteryMgr:DataCollectionService: stats => '

def preprocess_values(df):
    df['Timestamp'] = df['Timestamp'] - df['Timestamp'][0]
    # conversion from microseconds to seconds
    df['Timestamp'] = df['Timestamp'] / 1000
    return df

def calculate_power(df):
    df['power'] = (abs(df['BATTERY_PROPERTY_CURRENT_NOW']) / 1000 / 1000) * (df['EXTRA_VOLTAGE'] / 1000)
    return df

def trapezoid_method(df):
    return np.trapz(df['power'].values, df['Timestamp'].values), df['Timestamp'].values[-1]


def get_column_names(file):
    pattern = re.compile(HEADER_PATTERN)
    cols = []
    for line in open(file, encoding='utf-16'):
        if pattern.search(line):
            cols = line.split(HEADER_PATTERN)[1].split(',')
            cols = [col.strip() for col in cols]
            break
    return cols

def get_data(file):
    pattern = re.compile(DATA_PATTERN)
    data = []
    for line in open(file, encoding='utf-16'):
        if pattern.search(line):
            data.append(line.split(DATA_PATTERN)[1].strip('\n').split(','))

    return data

def generate_csv(data_path):
    cols = get_column_names(data_path)
    data = get_data(data_path)
    df = pd.DataFrame(data, columns=cols)
    # df.to_csv('test-paul-controls-bs3/batterymanager.csv', index=False)
    df['Timestamp'] = np.int64(df['Timestamp'])
    df['BATTERY_PROPERTY_CURRENT_NOW'] = np.int64(df['BATTERY_PROPERTY_CURRENT_NOW'])
    df['EXTRA_VOLTAGE'] = np.int64(df['EXTRA_VOLTAGE'])
    df = preprocess_values(df)
    df = calculate_power(df)
    # print(RAW_DATA)
    # print("Energy (J) = ", trapezoid_method(df))
    # df.to_csv(data_path.strip('.log') + '.csv', index=False)
    return df

def process_BM():
    df_aggregated = pd.DataFrame(columns=['device', 'app', 'app_details', 'is_record', 'is_wireless', 'repetition', 'energy(J)', 'length(s)'])
    for root, dirs, files in os.walk(".", topdown=False):
        for name in files:
            if name == 'battery_manager.log':
                # print(os.path.join(root, name))
                energy, length = trapezoid_method(generate_csv(os.path.join(root, name)))
                device = root.split('\\')[1]
                app = root.split('\\')[2].strip('-W')
                app_details = root.split('\\')[3]
                is_record = 'record' in root.split('\\')[4]
                is_wireless = '-W' in root.split('\\')[2]
                repetition = root.split('\\')[4].strip('record') if 'record' in root.split('\\')[4] else root.split('\\')[4].strip('replay')
                df_aggregated = pd.concat([df_aggregated, pd.DataFrame([[device, app, app_details, is_record, is_wireless, repetition, energy, length]], columns=['device', 'app', 'app_details', 'is_record', 'is_wireless', 'repetition', 'energy(J)', 'length(s)'])])
    print(df_aggregated)
    return df_aggregated

# %%
bm = process_BM().reset_index(drop=True)
bm
# Out:
#        device         app      app_details is_record is_wireless repetition  \
# 0     Quest-2   BeatSaber    PopStars-Easy      True       False          0
# 0     Quest-2   BeatSaber    PopStars-Easy     False       False        0.0
# 0     Quest-2   BeatSaber    PopStars-Easy     False       False        0.1
# 0     Quest-2   BeatSaber    PopStars-Easy     False       False        0.2
# 0     Quest-2   BeatSaber    PopStars-Hard      True       False          0
# ..        ...         ...              ...       ...         ...        ...
# 0   Quest-Pro  PistolWhip  BlackMagic-Easy     False       False        0.0
# 0   Quest-Pro  PistolWhip  BlackMagic-Easy     False       False        0.1
# 0   Quest-Pro  PistolWhip  BlackMagic-Easy     False       False        0.2
# 0   Quest-Pro  PistolWhip  BlackMagic-Easy      True        True          0
# 0   Quest-Pro  PistolWhip  BlackMagic-Easy     False        True        0.0
#
#       energy(J)  length(s)
# 0    868.569877    248.156
# 0    918.112823    245.407
# 0    925.825233    245.064
# 0    926.558247    243.108
# 0    909.141763    248.599
# ..          ...        ...
# 0    187.962075    230.749
# 0    308.306723    234.683
# 0    297.826784    233.879
# 0   1883.129026    230.713
# 0   2101.027088    236.976
#
# [77 rows x 8 columns]
# C:\Users\damla\AppData\Local\Temp\ipykernel_27724\450674611.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_aggregated = pd.concat([df_aggregated, pd.DataFrame([[device, app, app_details, is_record, is_wireless, repetition, energy, length]], columns=['device', 'app', 'app_details', 'is_record', 'is_wireless', 'repetition', 'energy(J)', 'length(s)'])])
#        device         app      app_details is_record is_wireless repetition  \
# 0     Quest-2   BeatSaber    PopStars-Easy      True       False          0
# 1     Quest-2   BeatSaber    PopStars-Easy     False       False        0.0
# 2     Quest-2   BeatSaber    PopStars-Easy     False       False        0.1
# 3     Quest-2   BeatSaber    PopStars-Easy     False       False        0.2
# 4     Quest-2   BeatSaber    PopStars-Hard      True       False          0
# ..        ...         ...              ...       ...         ...        ...
# 72  Quest-Pro  PistolWhip  BlackMagic-Easy     False       False        0.0
# 73  Quest-Pro  PistolWhip  BlackMagic-Easy     False       False        0.1
# 74  Quest-Pro  PistolWhip  BlackMagic-Easy     False       False        0.2
# 75  Quest-Pro  PistolWhip  BlackMagic-Easy      True        True          0
# 76  Quest-Pro  PistolWhip  BlackMagic-Easy     False        True        0.0
#
#       energy(J)  length(s)
# 0    868.569877    248.156
# 1    918.112823    245.407
# 2    925.825233    245.064
# 3    926.558247    243.108
# 4    909.141763    248.599
# ..          ...        ...
# 72   187.962075    230.749
# 73   308.306723    234.683
# 74   297.826784    233.879
# 75  1883.129026    230.713
# 76  2101.027088    236.976
#
# [77 rows x 8 columns]

# %%
# normalise energy
bm['energy(J)'] = bm['energy(J)'] / bm['length(s)']

# %% [markdown]
# # Plots

# %% [markdown]
# ### Totals per device

# %%
# set all the figure fonts to Arial
plt.rcParams['font.family'] = 'Arial'

# %%
import seaborn as sns
# boxplot with matplotlib
sns.boxplot(data=bm, x='device', y='energy(J)', showmeans=True, meanline=True)
# Out:
# <Axes: xlabel='device', ylabel='energy(J)'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for device in bm['device'].unique():
    tmp = bm[bm['device'] == device]

    for app in tmp['app'].unique():
        tmp2 = tmp[tmp['app'] == app]
        fig, ax = plt.subplots()
        sns.boxplot(data=tmp2, x='is_wireless', y='energy(J)', showmeans=True, meanline=True, ax=ax)
        ax.set_title(device + ' - ' + app)
        ax.set_ylabel('Energy (J)')
        ax.set_xlabel('Wireless')
        plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

for device in bm['device'].unique():
    tmp = bm[bm['device'] == device]

    for wireless in tmp['is_wireless'].unique():
        tmp2 = tmp[tmp['is_wireless'] == wireless]
        axes = sns.boxplot(data=tmp2, x='app_details', y='energy(J)', showmeans=True, meanline=True, ax=plt.gca())
        fig = axes.get_figure()
        if wireless:
            fig.suptitle("Energy consumption of wireless traces for " + device)
        else:
            fig.suptitle("Energy consumption of cabled traces for " + device)
        # set x-axis label
        axes.set_xlabel("Trace")
        # set y-axis label
        axes.set_ylabel("Energy(J)")

        plt.show()

# %% [markdown]
# # OVR GPU Metrics

# %%
import pandas as pd
import numpy as np
import os


def reset_timestamp(df):
    df['timestamp'] = df['timestamp'] - df['timestamp'][0]
    return df

def process_line(line):
    timestamp = line.split(' - ')[0]
    content = line.split(' - ')[1]
    key = str(content.split(':')[0].strip())
    value = float(content.split(':')[1].strip())
    return timestamp, key, value

def add_to_dataframe(df, timestamp, key, value):
    if key not in df.columns:
        df[key] = np.nan
    df.loc[timestamp, key] = value
    return df

def create_dataframe(file_path):
    df = pd.DataFrame()
    for line in open(file_path, 'r', encoding='utf-16'):
        if len(line) < 27:
            continue
        timestamp, key, value = process_line(line)
        df = add_to_dataframe(df, timestamp, key, value)

    df.index.name = 'timestamp'
    df = df.reset_index()
    # df = reset_timestamp(df)

    df['device'] = file_path.split('\\')[1]
    df['app'] = file_path.split('\\')[2].strip('-W')
    df['app_details'] = file_path.split('\\')[3]
    df['is_record'] = 'record' in file_path.split('\\')[4]
    df['is_wireless'] = '-W' in file_path.split('\\')[2]
    df['repetition'] = file_path.split('\\')[4].strip('record') if 'record' in file_path.split('\\')[4] else file_path.split('\\')[4].strip('replay')

    return df

def process_OVR():
    df_aggregated = pd.DataFrame()
    for root, dirs, files in os.walk(".", topdown=False):
        for name in files:
            if name == 'ovr_gpu_metrics.log':
                print(os.path.join(root, name))
                df_aggregated = pd.concat([df_aggregated, create_dataframe(os.path.join(root, name))]) 
    # df_aggregated
    return df_aggregated

# %%
ovr_df = process_OVR()
ovr_df
# Out:
# .\Quest-2\BeatSaber\PopStars-Easy\record0\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Easy\replay0.0\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Easy\replay0.1\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Easy\replay0.2\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Hard\record0\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Hard\replay0.0\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Hard\replay0.1\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Hard\replay0.2\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Medium\record0\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Medium\record1\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Medium\record2\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Medium\record3\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Medium\record4\ovr_gpu_metrics.log
# .\Quest-2\BeatSaber\PopStars-Medium\replay0.0\ovr_gpu_metrics.log
# 211  12/7/2023 4:30:50 PM      300047840.0    525000000.0          30.153
# 212  12/7/2023 4:30:51 PM      313039136.0    525000000.0          31.258
# 213  12/7/2023 4:30:52 PM      300441344.0    525000000.0          30.627
# 214  12/7/2023 4:30:53 PM      305568256.0    525000000.0          30.697
# 215  12/7/2023 4:30:54 PM      317626784.0    525000000.0          30.474
#
#      Preemptions / second  Avg Preemption Delay  % Vertex Fetch Stall  \
# 0                 168.880                26.754                 1.227
# 1                 203.993                15.596                 1.225
# 2                 199.131                11.821                 1.272
# 3                  69.703                 2.869                 1.571
# 4                 199.035                 8.325                 1.388
# ..                    ...                   ...                   ...
# 211               204.046               304.678                 1.486
# 212               216.728               348.529                 1.401
# 213               202.468               286.375                 1.476
# 214               203.733               335.984                 1.477
# 215               202.325               261.112                 1.522
#
#      % Texture Fetch Stall  % Texture L1 Miss  % Texture L2 Miss  ...  \
# 0                   32.984             30.415              7.687  ...
# 1                   31.561             30.418              7.554  ...
# 2                   31.142             30.539              7.216  ...
# 3                   51.449             31.137              7.377  ...
# 4                   31.402             30.661              7.491  ...
# ..                     ...                ...                ...  ...
# 211                 28.066             31.773              9.395  ...
# 212                 28.917             31.665              9.458  ...
# 213                 28.519             31.711              9.564  ...
# 214                 29.020             31.766              9.535  ...
# 215                 29.018             31.844              9.434  ...
#
#      % Nearest Filtered  % Linear Filtered  % Anisotropic Filtered  \
# 0                 0.002             99.986                   0.002
# 1                 0.002            100.000                   0.002
# 2                 0.002            100.000                   0.002
# 3                 0.001            100.000                   0.001
# 4                 0.002             99.986                   0.002
# ..                  ...                ...                     ...
# 211               0.156             99.826                   0.001
# 212               0.167             99.811                   0.001
# 213               0.155             99.855                   0.001
# 214               0.154             99.874                   0.001
# 215               0.148             99.873                   0.001
#
#      % Non-Base Level Textures     device         app      app_details  \
# 0                        0.018    Quest-2   BeatSaber    PopStars-Easy
# 1                        0.001    Quest-2   BeatSaber    PopStars-Easy
# 2                        0.001    Quest-2   BeatSaber    PopStars-Easy
# 3                        0.000    Quest-2   BeatSaber    PopStars-Easy
# 4                        0.016    Quest-2   BeatSaber    PopStars-Easy
# ..                         ...        ...         ...              ...
# 211                      0.025  Quest-Pro  PistolWhip  BlackMagic-Easy
# 212                      0.029  Quest-Pro  PistolWhip  BlackMagic-Easy
# 213                      0.000  Quest-Pro  PistolWhip  BlackMagic-Easy
# 214                      0.000  Quest-Pro  PistolWhip  BlackMagic-Easy
# 215                      0.000  Quest-Pro  PistolWhip  BlackMagic-Easy
#
#      is_record  is_wireless  repetition
# 0         True        False           0
# 1         True        False           0
# 2         True        False           0
# 3         True        False           0
# 4         True        False           0
# ..         ...          ...         ...
# 211      False         True         0.0
# 212      False         True         0.0
# 213      False         True         0.0
# 214      False         True         0.0
# 215      False         True         0.0
#
# [17754 rows x 59 columns]

# %%
ovr_df = ovr_df.reset_index()
ovr_df
# Out:
#        index             timestamp  Clocks / Second  GPU Frequency  \
# 0          0  12/5/2023 3:06:05 PM      266032064.0    525000000.0
# 1          1  12/5/2023 3:06:06 PM      270955808.0    525000000.0
# 2          2  12/5/2023 3:06:07 PM      267818560.0    525000000.0
# 3          3  12/5/2023 3:06:08 PM      212911472.0    525000000.0
# 4          4  12/5/2023 3:06:09 PM      263309680.0    525000000.0
# ...      ...                   ...              ...            ...
# 17749    211  12/7/2023 4:30:50 PM      300047840.0    525000000.0
# 17750    212  12/7/2023 4:30:51 PM      313039136.0    525000000.0
# 17751    213  12/7/2023 4:30:52 PM      300441344.0    525000000.0
# 17752    214  12/7/2023 4:30:53 PM      305568256.0    525000000.0
# 17753    215  12/7/2023 4:30:54 PM      317626784.0    525000000.0
#
#        GPU % Bus Busy  Preemptions / second  Avg Preemption Delay  \
# 0              33.312               168.880                26.754
# 1              31.584               203.993                15.596
# 2              29.295               199.131                11.821
# 3              49.151                69.703                 2.869
# 4              29.755               199.035                 8.325
# ...               ...                   ...                   ...
# 17749          30.153               204.046               304.678
# 17750          31.258               216.728               348.529
# 17751          30.627               202.468               286.375
# 17752          30.697               203.733               335.984
# 17753          30.474               202.325               261.112
#
#        % Vertex Fetch Stall  % Texture Fetch Stall  % Texture L1 Miss  ...  \
# 0                     1.227                 32.984             30.415  ...
# 1                     1.225                 31.561             30.418  ...
# 2                     1.272                 31.142             30.539  ...
# 3                     1.571                 51.449             31.137  ...
# 4                     1.388                 31.402             30.661  ...
# ...                     ...                    ...                ...  ...
# 17749                 1.486                 28.066             31.773  ...
# 17750                 1.401                 28.917             31.665  ...
# 17751                 1.476                 28.519             31.711  ...
# 17752                 1.477                 29.020             31.766  ...
# 17753                 1.522                 29.018             31.844  ...
#
#        % Nearest Filtered  % Linear Filtered  % Anisotropic Filtered  \
# 0                   0.002             99.986                   0.002
# 1                   0.002            100.000                   0.002
# 2                   0.002            100.000                   0.002
# 3                   0.001            100.000                   0.001
# 4                   0.002             99.986                   0.002
# ...                   ...                ...                     ...
# 17749               0.156             99.826                   0.001
# 17750               0.167             99.811                   0.001
# 17751               0.155             99.855                   0.001
# 17752               0.154             99.874                   0.001
# 17753               0.148             99.873                   0.001
#
#        % Non-Base Level Textures     device         app      app_details  \
# 0                          0.018    Quest-2   BeatSaber    PopStars-Easy
# 1                          0.001    Quest-2   BeatSaber    PopStars-Easy
# 2                          0.001    Quest-2   BeatSaber    PopStars-Easy
# 3                          0.000    Quest-2   BeatSaber    PopStars-Easy
# 4                          0.016    Quest-2   BeatSaber    PopStars-Easy
# ...                          ...        ...         ...              ...
# 17749                      0.025  Quest-Pro  PistolWhip  BlackMagic-Easy
# 17750                      0.029  Quest-Pro  PistolWhip  BlackMagic-Easy
# 17751                      0.000  Quest-Pro  PistolWhip  BlackMagic-Easy
# 17752                      0.000  Quest-Pro  PistolWhip  BlackMagic-Easy
# 17753                      0.000  Quest-Pro  PistolWhip  BlackMagic-Easy
#
#        is_record  is_wireless  repetition
# 0           True        False           0
# 1           True        False           0
# 2           True        False           0
# 3           True        False           0
# 4           True        False           0
# ...          ...          ...         ...
# 17749      False         True         0.0
# 17750      False         True         0.0
# 17751      False         True         0.0
# 17752      False         True         0.0
# 17753      False         True         0.0
#
# [17754 rows x 60 columns]

# %%
ovr_df.to_csv('ovr_overall.csv', index=False)
